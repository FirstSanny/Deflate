# %%
using DataFrames

# %%
using IterativeSolvers
using Plots
using MatrixMarket
include("D:/git/Deflate/SimpleProlongations.jl")
include("D:/git/Deflate/AggregationbasedProlongation.jl")
include("D:/git/Deflate/ReductionbasedProlongation.jl")
# Out:
# WARNING: replacing module simpleProlongations
# WARNING: replacing module AggregationbasedProlongation
# WARNING: replacing module ReductionbasedProlongation
# ReductionbasedProlongation

# %%
# Solves the System Ax=b with de Deflation-Operator R
function solve(A, b, R, useM3)
    n = size(A,1)
    
    P = transpose(R)
    
    Q = P*inv(R*A*P)*R
    
    if(useM3)
        PN = inv(Diagonal(A))*(I - A * Q) + Q
    else
        PN = I - A * Q + Q
    end
        
        
    gmres(A, b; tol = 1/100000000, Pl = lufact(PN), log = true)   
end
# Out:
# solve (generic function with 2 methods)

# %%
function getA()
    mmread("bcsstm26.mtx")
end
# Out:
# getA (generic function with 1 method)

# %%
A = getA()
n = size(A,1)
b = ones(Float64, n,1)
useM3 = false
# solve
@time x1, history1 = solve(A, b, simpleProlongations.prolongation1(n), useM3)
@time x2, history2 = solve(A, b, simpleProlongations.prolongation2(n), useM3)
@time x3, history3 = solve(A, b, AggregationbasedProlongation.prolongationAggregation(A), useM3)
@time x4, history4 = solve(A, b, ReductionbasedProlongation.prolongationReduction(getA()), useM3)

# plot
#gr()
pyplot()
history1data = history1.data[:resnorm]
history2data = history2.data[:resnorm]
history3data = history3.data[:resnorm]
history4data = history4.data[:resnorm]

plot(history1data, xlabel="iterations", ylabel="res-norm", label="simple prolongation", yscale = :log10)
plot!(history2data, label="prolongation with weights")
plot!(history3data, label="aggregation-based prolongation")
plot!(history4data, label="reduction-based prolongation")
#savefig("prolongations.png")
# Out:
#   4.416954 seconds (68.08 k allocations: 221.141 MiB, 3.34% gc time)
#   7.001447 seconds (68.08 k allocations: 235.717 MiB, 2.93% gc time)
#   7.339865 seconds (48.99 M allocations: 1.203 GiB, 6.76% gc time)
#   7.771358 seconds (15.44 M allocations: 880.507 MiB, 4.69% gc time)
# WARNING: scale log is unsupported with Plots.PyPlotBackend().  Choose from: Symbol[:identity, :ln, :log2, :log10]
